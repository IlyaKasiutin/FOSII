# %%
from nn.train_dichalcogenides import train_gnn_dichalcogenides
from nn.optimizers.adam import Adam


optimizer = Adam(learning_rate=0.001)

model, history = train_gnn_dichalcogenides(
    structures_dir="dichalcogenides_public/structures/",
    targets_file="dichalcogenides_public/targets.csv",
    cutoff_radius=5.0,
    node_features=5,
    edge_features=3,
    hidden_features=64,
    num_layers=3,
    epochs=50,
    batch_size=32,
    learning_rate=0.01,
    # optimizer=optimizer,
    train_split=0.8,
    max_samples=500,  # Use all samples
    # gradient_clip = 10.0,
    verbose=True
)
# Out:
# Loading dataset...
# 100%|██████████| 500/500 [00:24<00:00, 20.28it/s]
# Normalizing features...
# Loaded 500 samples
# Node features shape: (190, 5)
# Edge features shape: (3508, 3)
# Targets shape: (500, 1)
# Target range: [0.1721, 1.8106]
#
# Train samples: 400
# Validation samples: 100
#
# Model created:
#   Node features: 5
#   Edge features: 3
#   Hidden features: 64
#   Number of layers: 3
#   Optimizer: SGD (learning_rate=0.01)
#
# Training model...
# 100%|██████████| 13/13 [00:07<00:00,  1.79it/s]
# Epoch 1/50 - loss: 10982.5448
# 100%|██████████| 13/13 [00:08<00:00,  1.62it/s]
# Epoch 2/50 - loss: 8173.6428
# 100%|██████████| 13/13 [00:07<00:00,  1.63it/s]
# Epoch 3/50 - loss: 7673.3802
# 100%|██████████| 13/13 [00:07<00:00,  1.66it/s]
# Epoch 4/50 - loss: 7238.4143
# 100%|██████████| 13/13 [00:06<00:00,  1.86it/s]
# Epoch 5/50 - loss: 6800.6968
# 100%|██████████| 13/13 [00:07<00:00,  1.86it/s]
# Epoch 6/50 - loss: 6283.5366
# ...
